# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.6.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
cd /kaggle
# Out:
# /kaggle

# %%
#image https://drive.google.com/file/d/11lE_69AXIOM8h0oKKCmXOS08AAXD3252/view?usp=drive_link
#anno https://drive.google.com/file/d/1f2j3EiOf5McgpmLW-jrWdNs2jjd5WQxN/view?usp=drive_link
# !gdown 11lE_69AXIOM8h0oKKCmXOS08AAXD3252
# !gdown 1f2j3EiOf5McgpmLW-jrWdNs2jjd5WQxN
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=11lE_69AXIOM8h0oKKCmXOS08AAXD3252
# From (redirected): https://drive.google.com/uc?id=11lE_69AXIOM8h0oKKCmXOS08AAXD3252&confirm=t&uuid=99302d1a-0048-4628-8b8c-c27511455012
# To: /kaggle/Images.zip
# 100%|██████████████████████████████████████| 10.2G/10.2G [02:58<00:00, 57.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1f2j3EiOf5McgpmLW-jrWdNs2jjd5WQxN
# To: /kaggle/labelTxt.zip
# 100%|███████████████████████████████████████| 2.08M/2.08M [00:00<00:00, 177MB/s]

# %%
# !mkdir  /kaggle/working/data

# !unzip Images.zip -d /kaggle/working/data

# Unzip labelTxt.zip into that folder
# !unzip labelTxt.zip -d /kaggle/working/data
# Out:
# Archive:  Images.zip
#    creating: /kaggle/working/data/Images/
#   inflating: /kaggle/working/data/Images/P0000.png
#   inflating: /kaggle/working/data/Images/P0001.png
#   inflating: /kaggle/working/data/Images/P0002.png
#   inflating: /kaggle/working/data/Images/P0005.png
#   inflating: /kaggle/working/data/Images/P0008.png
#   inflating: /kaggle/working/data/Images/P0010.png
#   inflating: /kaggle/working/data/Images/P0011.png
#   inflating: /kaggle/working/data/Images/P0012.png
#   inflating: /kaggle/working/data/Images/P0013.png
#   inflating: /kaggle/working/data/Images/P0018.png
#   inflating: /kaggle/working/data/Images/P0020.png
#   inflating: /kaggle/working/data/Images/P0021.png
#   inflating: /kaggle/working/data/Images/P0022.png
#   inflating: /kaggle/working/data/Images/P0023.png
#   inflating: /kaggle/working/data/Images/P0025.png
#   inflating: /kaggle/working/data/Images/P0029.png
#   inflating: /kaggle/working/data/Images/P0030.png
#   inflating: /kaggle/working/data/Images/P0032.png
#   inflating: /kaggle/working/data/Images/P0036.png
#   inflating: /kaggle/working/data/Images/P0038.png
#   inflating: /kaggle/working/data/Images/P0039.png
#   inflating: /kaggle/working/data/Images/P0041.png
#   inflating: /kaggle/working/data/Images/P0042.png
#   inflating: /kaggle/working/data/Images/P0044.png
#   inflating: /kaggle/working/data/Images/P0049.png
#   inflating: /kaggle/working/data/Images/P0050.png
#   inflating: /kaggle/working/data/Images/P0052.png
#   inflating: /kaggle/working/data/Images/P0054.png
#   inflating: /kaggle/working/data/Images/P0058.png
#   inflating: /kaggle/working/data/Images/P0061.png
#   inflating: /kaggle/working/data/Images/P0063.png
#   inflating: /kaggle/working/data/Images/P0064.png
#   inflating: /kaggle/working/data/Images/P0065.png
#   inflating: /kaggle/working/data/Images/P0066.png
#   inflating: /kaggle/working/data/Images/P0067.png
#   inflating: /kaggle/working/data/Images/P0068.png
#   inflating: /kaggle/working/data/Images/P0070.png
#   inflating: /kaggle/working/data/Images/P0071.png
#   inflating: /kaggle/working/data/Images/P0074.png
#   inflating: /kaggle/working/data/Images/P0076.png
#   inflating: /kaggle/working/data/Images/P0078.png
#   inflating: /kaggle/working/data/Images/P0082.png
#   inflating: /kaggle/working/data/Images/P0083.png
#   inflating: /kaggle/working/data/Images/P0085.png
#   inflating: /kaggle/working/data/Images/P0087.png
#   inflating: /kaggle/working/data/Images/P0091.png
#   inflating: /kaggle/working/data/Images/P0093.png
#   inflating: /kaggle/working/data/Images/P0094.png
#   inflating: /kaggle/working/data/Images/P0095.png
#   inflating: /kaggle/working/data/Images/P0096.png
#   inflating: /kaggle/working/data/Images/P0098.png
#   inflating: /kaggle/working/data/Images/P0099.png
#   inflating: /kaggle/working/data/Images/P0100.png
#   inflating: /kaggle/working/data/Images/P0103.png
#   inflating: /kaggle/working/data/Images/P0109.png
#   inflating: /kaggle/working/data/Images/P0111.png
#   inflating: /kaggle/working/data/Images/P0113.png
#   inflating: /kaggle/working/data/Images/P0116.png
#   inflating: /kaggle/working/data/Images/P0119.png
#   inflating: /kaggle/working/data/Images/P0122.png
#   inflating: /kaggle/working/data/Images/P0124.png
#   inflating: /kaggle/working/data/Images/P0126.png
#   inflating: /kaggle/working/data/Images/P0129.png
#   inflating: /kaggle/working/data/Images/P0133.png
#   inflating: /kaggle/working/data/Images/P0136.png
#   inflating: /kaggle/working/data/Images/P0139.png
#   inflating: /kaggle/working/data/Images/P0140.png
#   inflating: /kaggle/working/data/Images/P0141.png
#   inflating: /kaggle/working/data/Images/P0142.png
#   inflating: /kaggle/working/data/Images/P0144.png
#   inflating: /kaggle/working/data/Images/P0147.png
#   inflating: /kaggle/working/data/Images/P0149.png
#   inflating: /kaggle/working/data/Images/P0151.png
#   inflating: /kaggle/working/data/Images/P0152.png
#   inflating: /kaggle/working/data/Images/P0158.png
#   inflating: /kaggle/working/data/Images/P0159.png
#   inflating: /kaggle/working/data/Images/P0160.png
#   inflating: /kaggle/working/data/Images/P0162.png
#   inflating: /kaggle/working/data/Images/P0163.png
#   inflating: /kaggle/working/data/Images/P0164.png
#   inflating: /kaggle/working/data/Images/P0167.png
#   inflating: /kaggle/working/data/Images/P0169.png
#   inflating: /kaggle/working/data/Images/P0171.png
#   inflating: /kaggle/working/data/Images/P0172.png
#   inflating: /kaggle/working/data/Images/P0174.png
#   inflating: /kaggle/working/data/Images/P0176.png
#   inflating: /kaggle/working/data/Images/P0178.png
#   inflating: /kaggle/working/data/Images/P0183.png
#   inflating: /kaggle/working/data/Images/P0187.png
#   inflating: /kaggle/working/data/Images/P0188.png
#   inflating: /kaggle/working/data/Images/P0190.png
#   inflating: /kaggle/working/data/Images/P0200.png
#   inflating: /kaggle/working/data/Images/P0201.png
#   inflating: /kaggle/working/data/Images/P0202.png
#   inflating: /kaggle/working/data/Images/P0203.png
#   inflating: /kaggle/working/data/Images/P0204.png
#   inflating: /kaggle/working/data/Images/P0207.png
#   inflating: /kaggle/working/data/Images/P0209.png
#   inflating: /kaggle/working/data/Images/P0210.png
#   inflating: /kaggle/working/data/Images/P0212.png
#   inflating: /kaggle/working/data/Images/P0215.png
#   inflating: /kaggle/working/data/Images/P0218.png
#   inflating: /kaggle/working/data/Images/P0219.png
#   inflating: /kaggle/working/data/Images/P0220.png
#   inflating: /kaggle/working/data/Images/P0221.png
#   inflating: /kaggle/working/data/Images/P0222.png
#   inflating: /kaggle/working/data/Images/P0223.png
#   inflating: /kaggle/working/data/Images/P0224.png
#   inflating: /kaggle/working/data/Images/P0225.png
#   inflating: /kaggle/working/data/Images/P0226.png
#   inflating: /kaggle/working/data/Images/P0227.png
#   inflating: /kaggle/working/data/Images/P0229.png
#   inflating: /kaggle/working/data/Images/P0232.png
#   inflating: /kaggle/working/data/Images/P0233.png
#   inflating: /kaggle/working/data/Images/P0235.png
#   inflating: /kaggle/working/data/Images/P0236.png
#   inflating: /kaggle/working/data/Images/P0238.png
#   inflating: /kaggle/working/data/Images/P0241.png
#   inflating: /kaggle/working/data/Images/P0244.png
#   inflating: /kaggle/working/data/Images/P0248.png
#   inflating: /kaggle/working/data/Images/P0250.png
#   inflating: /kaggle/working/data/Images/P0251.png
#   inflating: /kaggle/working/data/Images/P0252.png
#   inflating: /kaggle/working/data/Images/P0254.png
#   inflating: /kaggle/working/data/Images/P0255.png
#   inflating: /kaggle/working/data/Images/P0256.png
#   inflating: /kaggle/working/data/Images/P0258.png
#   inflating: /kaggle/working/data/Images/P0260.png
#   inflating: /kaggle/working/data/Images/P0263.png
#   inflating: /kaggle/working/data/Images/P0264.png
#   inflating: /kaggle/working/data/Images/P0270.png
#   inflating: /kaggle/working/data/Images/P0272.png
#   inflating: /kaggle/working/data/Images/P0273.png
#   inflating: /kaggle/working/data/Images/P0275.png
#   inflating: /kaggle/working/data/Images/P0276.png
#   inflating: /kaggle/working/data/Images/P0280.png
#   inflating: /kaggle/working/data/Images/P0281.png
#   inflating: /kaggle/working/data/Images/P0282.png
#   inflating: /kaggle/working/data/Images/P0283.png
#   inflating: /kaggle/working/data/Images/P0285.png
#   inflating: /kaggle/working/data/Images/P0286.png
#   inflating: /kaggle/working/data/Images/P0288.png
#   inflating: /kaggle/working/data/Images/P0289.png
#   inflating: /kaggle/working/data/Images/P0292.png
#   inflating: /kaggle/working/data/Images/P0293.png
#   inflating: /kaggle/working/data/Images/P0294.png
#   inflating: /kaggle/working/data/Images/P0296.png
#   inflating: /kaggle/working/data/Images/P0299.png
#   inflating: /kaggle/working/data/Images/P0301.png
#   inflating: /kaggle/working/data/Images/P0303.png
#   inflating: /kaggle/working/data/Images/P0308.png
#   inflating: /kaggle/working/data/Images/P0310.png
#   inflating: /kaggle/working/data/Images/P0313.png
#   inflating: /kaggle/working/data/Images/P0314.png
#   inflating: /kaggle/working/data/Images/P0315.png
#   inflating: /kaggle/working/data/Images/P0317.png
#   inflating: /kaggle/working/data/Images/P0321.png
#   inflating: /kaggle/working/data/Images/P0322.png
#   inflating: /kaggle/working/data/Images/P0324.png
#   inflating: /kaggle/working/data/Images/P0327.png
#   inflating: /kaggle/working/data/Images/P0330.png
#   inflating: /kaggle/working/data/Images/P0332.png
#   inflating: /kaggle/working/data/Images/P0334.png
#   inflating: /kaggle/working/data/Images/P0335.png
#   inflating: /kaggle/working/data/Images/P0337.png
#   inflating: /kaggle/working/data/Images/P0338.png
#   inflating: /kaggle/working/data/Images/P0339.png
#   inflating: /kaggle/working/data/Images/P0340.png
#   inflating: /kaggle/working/data/Images/P0343.png
#   inflating: /kaggle/working/data/Images/P0344.png
#   inflating: /kaggle/working/data/Images/P0345.png
#   inflating: /kaggle/working/data/Images/P0346.png
#   inflating: /kaggle/working/data/Images/P0349.png
#   inflating: /kaggle/working/data/Images/P0350.png
#   inflating: /kaggle/working/data/Images/P0355.png
#   inflating: /kaggle/working/data/Images/P0357.png
#   inflating: /kaggle/working/data/Images/P0358.png
#   inflating: /kaggle/working/data/Images/P0360.png
#   inflating: /kaggle/working/data/Images/P0361.png
#   inflating: /kaggle/working/data/Images/P0362.png
#   inflating: /kaggle/working/data/Images/P0363.png
#   inflating: /kaggle/working/data/Images/P0364.png
#   inflating: /kaggle/working/data/Images/P0365.png
#   inflating: /kaggle/working/data/Images/P0366.png
#   inflating: /kaggle/working/data/Images/P0367.png
#   inflating: /kaggle/working/data/Images/P0370.png
#   inflating: /kaggle/working/data/Images/P0371.png
#   inflating: /kaggle/working/data/Images/P0373.png
#   inflating: /kaggle/working/data/Images/P0376.png
#   inflating: /kaggle/working/data/Images/P0378.png
#   inflating: /kaggle/working/data/Images/P0379.png
#   inflating: /kaggle/working/data/Images/P0380.png
#   inflating: /kaggle/working/data/Images/P0381.png
#   inflating: /kaggle/working/data/Images/P0383.png
#   inflating: /kaggle/working/data/Images/P0384.png
#   inflating: /kaggle/working/data/Images/P0386.png
#   inflating: /kaggle/working/data/Images/P0387.png
#   inflating: /kaggle/working/data/Images/P0388.png
#   inflating: /kaggle/working/data/Images/P0389.png
#   inflating: /kaggle/working/data/Images/P0391.png
#   inflating: /kaggle/working/data/Images/P0392.png
#   inflating: /kaggle/working/data/Images/P0393.png
#   inflating: /kaggle/working/data/Images/P0395.png
#   inflating: /kaggle/working/data/Images/P0400.png
#   inflating: /kaggle/working/data/Images/P0401.png
#   inflating: /kaggle/working/data/Images/P0404.png
#   inflating: /kaggle/working/data/Images/P0405.png
#   inflating: /kaggle/working/data/Images/P0406.png
#   inflating: /kaggle/working/data/Images/P0407.png
#   inflating: /kaggle/working/data/Images/P0413.png
#   inflating: /kaggle/working/data/Images/P0415.png
#   inflating: /kaggle/working/data/Images/P0416.png
#   inflating: /kaggle/working/data/Images/P0417.png
#   inflating: /kaggle/working/data/Images/P0418.png
#   inflating: /kaggle/working/data/Images/P0419.png
#   inflating: /kaggle/working/data/Images/P0421.png
#   inflating: /kaggle/working/data/Images/P0422.png
#   inflating: /kaggle/working/data/Images/P0424.png
#   inflating: /kaggle/working/data/Images/P0425.png
#   inflating: /kaggle/working/data/Images/P0426.png
#   inflating: /kaggle/working/data/Images/P0428.png
#   inflating: /kaggle/working/data/Images/P0430.png
#   inflating: /kaggle/working/data/Images/P0431.png
#   inflating: /kaggle/working/data/Images/P0434.png
#   inflating: /kaggle/working/data/Images/P0435.png
#   inflating: /kaggle/working/data/Images/P0436.png
#   inflating: /kaggle/working/data/Images/P0437.png
#   inflating: /kaggle/working/data/Images/P0438.png
#   inflating: /kaggle/working/data/Images/P0439.png
#   inflating: /kaggle/working/data/Images/P0440.png
#   inflating: /kaggle/working/data/Images/P0441.png
#   inflating: /kaggle/working/data/Images/P0442.png
#   inflating: /kaggle/working/data/Images/P0443.png
#   inflating: /kaggle/working/data/Images/P0445.png
#   inflating: /kaggle/working/data/Images/P0446.png
#   inflating: /kaggle/working/data/Images/P0448.png
#   inflating: /kaggle/working/data/Images/P0450.png
#   inflating: /kaggle/working/data/Images/P0452.png
#   inflating: /kaggle/working/data/Images/P0453.png
#   inflating: /kaggle/working/data/Images/P0455.png
#   inflating: /kaggle/working/data/Images/P0458.png
#   inflating: /kaggle/working/data/Images/P0459.png
#   inflating: /kaggle/working/data/Images/P0460.png
#   inflating: /kaggle/working/data/Images/P0461.png
#   inflating: /kaggle/working/data/Images/P0464.png
#   inflating: /kaggle/working/data/Images/P0465.png
#   inflating: /kaggle/working/data/Images/P0468.png
#   inflating: /kaggle/working/data/Images/P0469.png
#   inflating: /kaggle/working/data/Images/P0471.png
#   inflating: /kaggle/working/data/Images/P0475.png
#   inflating: /kaggle/working/data/Images/P0477.png
#   inflating: /kaggle/working/data/Images/P0478.png
#   inflating: /kaggle/working/data/Images/P0479.png
#   inflating: /kaggle/working/data/Images/P0481.png
#   inflating: /kaggle/working/data/Images/P0482.png
#   inflating: /kaggle/working/data/Images/P0483.png
#   inflating: /kaggle/working/data/Images/P0484.png
#   inflating: /kaggle/working/data/Images/P0487.png
#   inflating: /kaggle/working/data/Images/P0488.png
#   inflating: /kaggle/working/data/Images/P0489.png
#   inflating: /kaggle/working/data/Images/P0493.png
#   inflating: /kaggle/working/data/Images/P0494.png
#   inflating: /kaggle/working/data/Images/P0495.png
#   inflating: /kaggle/working/data/Images/P0503.png
#   inflating: /kaggle/working/data/Images/P0504.png
#   inflating: /kaggle/working/data/Images/P0505.png
#   inflating: /kaggle/working/data/Images/P0510.png
#   inflating: /kaggle/working/data/Images/P0512.png
#   inflating: /kaggle/working/data/Images/P0516.png
#   inflating: /kaggle/working/data/Images/P0517.png
#   inflating: /kaggle/working/data/Images/P0520.png
#   inflating: /kaggle/working/data/Images/P0521.png
#   inflating: /kaggle/working/data/Images/P0522.png
#   inflating: /kaggle/working/data/Images/P0527.png
#   inflating: /kaggle/working/data/Images/P0531.png
#   inflating: /kaggle/working/data/Images/P0533.png
#   inflating: /kaggle/working/data/Images/P0535.png
#   inflating: /kaggle/working/data/Images/P0537.png
#   inflating: /kaggle/working/data/Images/P0538.png
#   inflating: /kaggle/working/data/Images/P0541.png
#   inflating: /kaggle/working/data/Images/P0542.png
#   inflating: /kaggle/working/data/Images/P0544.png
#   inflating: /kaggle/working/data/Images/P0546.png
#   inflating: /kaggle/working/data/Images/P0548.png
#   inflating: /kaggle/working/data/Images/P0549.png
#   inflating: /kaggle/working/data/Images/P0553.png
#   inflating: /kaggle/working/data/Images/P0554.png
#   inflating: /kaggle/working/data/Images/P0555.png
#   inflating: /kaggle/working/data/Images/P0556.png
#   inflating: /kaggle/working/data/Images/P0562.png
#   inflating: /kaggle/working/data/Images/P0563.png
#   inflating: /kaggle/working/data/Images/P0565.png
#   inflating: /kaggle/working/data/Images/P0567.png
#   inflating: /kaggle/working/data/Images/P0568.png
#   inflating: /kaggle/working/data/Images/P0569.png
#   inflating: /kaggle/working/data/Images/P0571.png
#   inflating: /kaggle/working/data/Images/P0572.png
#   inflating: /kaggle/working/data/Images/P0573.png
#   inflating: /kaggle/working/data/Images/P0578.png
#   inflating: /kaggle/working/data/Images/P0580.png
#   inflating: /kaggle/working/data/Images/P0581.png
#   inflating: /kaggle/working/data/Images/P0582.png
#   inflating: /kaggle/working/data/Images/P0586.png
#   inflating: /kaggle/working/data/Images/P0587.png
#   inflating: /kaggle/working/data/Images/P0591.png
#   inflating: /kaggle/working/data/Images/P0593.png
#   inflating: /kaggle/working/data/Images/P0595.png
#   inflating: /kaggle/working/data/Images/P0596.png
#   inflating: /kaggle/working/data/Images/P0597.png
#   inflating: /kaggle/working/data/Images/P0601.png
#   inflating: /kaggle/working/data/Images/P0602.png
#   inflating: /kaggle/working/data/Images/P0603.png
#   inflating: /kaggle/working/data/Images/P0605.png
#   inflating: /kaggle/working/data/Images/P0607.png
#   inflating: /kaggle/working/data/Images/P0609.png
#   inflating: /kaggle/working/data/Images/P0610.png
#   inflating: /kaggle/working/data/Images/P0611.png
#   inflating: /kaggle/working/data/Images/P0612.png
#   inflating: /kaggle/working/data/Images/P0614.png
#   inflating: /kaggle/working/data/Images/P0617.png
#   inflating: /kaggle/working/data/Images/P0618.png
#   inflating: /kaggle/working/data/Images/P0619.png
#   inflating: /kaggle/working/data/Images/P0620.png
#   inflating: /kaggle/working/data/Images/P0624.png
#   inflating: /kaggle/working/data/Images/P0625.png
#   inflating: /kaggle/working/data/Images/P0626.png
#   inflating: /kaggle/working/data/Images/P0627.png
#   inflating: /kaggle/working/data/Images/P0629.png
#   inflating: /kaggle/working/data/Images/P0630.png
#   inflating: /kaggle/working/data/Images/P0631.png
#   inflating: /kaggle/working/data/Images/P0632.png
#   inflating: /kaggle/working/data/Images/P0634.png
#   inflating: /kaggle/working/data/Images/P0637.png
#   inflating: /kaggle/working/data/Images/P0638.png
#   inflating: /kaggle/working/data/Images/P0641.png
#   inflating: /kaggle/working/data/Images/P0642.png
#   inflating: /kaggle/working/data/Images/P0646.png
#   inflating: /kaggle/working/data/Images/P0648.png
#   inflating: /kaggle/working/data/Images/P0649.png
#   inflating: /kaggle/working/data/Images/P0652.png
#   inflating: /kaggle/working/data/Images/P0653.png
#   inflating: /kaggle/working/data/Images/P0656.png
#   inflating: /kaggle/working/data/Images/P0658.png
#   inflating: /kaggle/working/data/Images/P0664.png
#   inflating: /kaggle/working/data/Images/P0666.png
#   inflating: /kaggle/working/data/Images/P0668.png
#   inflating: /kaggle/working/data/Images/P0676.png
#   inflating: /kaggle/working/data/Images/P0677.png
#   inflating: /kaggle/working/data/Images/P0685.png
#   inflating: /kaggle/working/data/Images/P0687.png
#   inflating: /kaggle/working/data/Images/P0688.png
#   inflating: /kaggle/working/data/Images/P0689.png
#   inflating: /kaggle/working/data/Images/P0691.png
#   inflating: /kaggle/working/data/Images/P0692.png
#   inflating: /kaggle/working/data/Images/P0693.png
#   inflating: /kaggle/working/data/Images/P0695.png
#   inflating: /kaggle/working/data/Images/P0697.png
#   inflating: /kaggle/working/data/Images/P0699.png
#   inflating: /kaggle/working/data/Images/P0700.png
#   inflating: /kaggle/working/data/Images/P0702.png
#   inflating: /kaggle/working/data/Images/P0703.png
#   inflating: /kaggle/working/data/Images/P0707.png
#   inflating: /kaggle/working/data/Images/P0711.png
#   inflating: /kaggle/working/data/Images/P0713.png
#   inflating: /kaggle/working/data/Images/P0714.png
#   inflating: /kaggle/working/data/Images/P0716.png
#   inflating: /kaggle/working/data/Images/P0719.png
#   inflating: /kaggle/working/data/Images/P0722.png
#   inflating: /kaggle/working/data/Images/P0723.png
#   inflating: /kaggle/working/data/Images/P0724.png
#   inflating: /kaggle/working/data/Images/P0726.png
#   inflating: /kaggle/working/data/Images/P0727.png
#   inflating: /kaggle/working/data/Images/P0728.png
#   inflating: /kaggle/working/data/Images/P0730.png
#   inflating: /kaggle/working/data/Images/P0731.png
#   inflating: /kaggle/working/data/Images/P0732.png
#   inflating: /kaggle/working/data/Images/P0733.png
#   inflating: /kaggle/working/data/Images/P0734.png
#   inflating: /kaggle/working/data/Images/P0737.png
#   inflating: /kaggle/working/data/Images/P0738.png
#   inflating: /kaggle/working/data/Images/P0743.png
#   inflating: /kaggle/working/data/Images/P0744.png
#   inflating: /kaggle/working/data/Images/P0745.png
#   inflating: /kaggle/working/data/Images/P0746.png
#   inflating: /kaggle/working/data/Images/P0750.png
#   inflating: /kaggle/working/data/Images/P0753.png
#   inflating: /kaggle/working/data/Images/P0754.png
#   inflating: /kaggle/working/data/Images/P0755.png
#   inflating: /kaggle/working/data/Images/P0757.png
#   inflating: /kaggle/working/data/Images/P0759.png
#   inflating: /kaggle/working/data/Images/P0760.png
#   inflating: /kaggle/working/data/Images/P0762.png
#   inflating: /kaggle/working/data/Images/P0766.png
#   inflating: /kaggle/working/data/Images/P0768.png
#   inflating: /kaggle/working/data/Images/P0769.png
#   inflating: /kaggle/working/data/Images/P0775.png
#   inflating: /kaggle/working/data/Images/P0777.png
#   inflating: /kaggle/working/data/Images/P0778.png
#   inflating: /kaggle/working/data/Images/P0779.png
#   inflating: /kaggle/working/data/Images/P0780.png
#   inflating: /kaggle/working/data/Images/P0781.png
#   inflating: /kaggle/working/data/Images/P0782.png
#   inflating: /kaggle/working/data/Images/P0783.png
#   inflating: /kaggle/working/data/Images/P0785.png
#   inflating: /kaggle/working/data/Images/P0786.png
#   inflating: /kaggle/working/data/Images/P0790.png
#   inflating: /kaggle/working/data/Images/P0792.png
#   inflating: /kaggle/working/data/Images/P0794.png
#   inflating: /kaggle/working/data/Images/P0800.png
#   inflating: /kaggle/working/data/Images/P0803.png
#   inflating: /kaggle/working/data/Images/P0804.png
#   inflating: /kaggle/working/data/Images/P0805.png
#   inflating: /kaggle/working/data/Images/P0806.png
#   inflating: /kaggle/working/data/Images/P0809.png
#   inflating: /kaggle/working/data/Images/P0810.png
#   inflating: /kaggle/working/data/Images/P0817.png
#   inflating: /kaggle/working/data/Images/P0818.png
#   inflating: /kaggle/working/data/Images/P0819.png
#   inflating: /kaggle/working/data/Images/P0821.png
#   inflating: /kaggle/working/data/Images/P0823.png
#   inflating: /kaggle/working/data/Images/P0825.png
#   inflating: /kaggle/working/data/Images/P0826.png
#   inflating: /kaggle/working/data/Images/P0827.png
#   inflating: /kaggle/working/data/Images/P0828.png
#   inflating: /kaggle/working/data/Images/P0829.png
#   inflating: /kaggle/working/data/Images/P0831.png
#   inflating: /kaggle/working/data/Images/P0832.png
#   inflating: /kaggle/working/data/Images/P0835.png
#   inflating: /kaggle/working/data/Images/P0840.png
#   inflating: /kaggle/working/data/Images/P0843.png
#   inflating: /kaggle/working/data/Images/P0845.png
#   inflating: /kaggle/working/data/Images/P0846.png
#   inflating: /kaggle/working/data/Images/P0848.png
#   inflating: /kaggle/working/data/Images/P0849.png
#   inflating: /kaggle/working/data/Images/P0850.png
#   inflating: /kaggle/working/data/Images/P0851.png
#   inflating: /kaggle/working/data/Images/P0853.png
#   inflating: /kaggle/working/data/Images/P0855.png
#   inflating: /kaggle/working/data/Images/P0856.png
#   inflating: /kaggle/working/data/Images/P0857.png
#   inflating: /kaggle/working/data/Images/P0860.png
#   inflating: /kaggle/working/data/Images/P0861.png
#   inflating: /kaggle/working/data/Images/P0867.png
#   inflating: /kaggle/working/data/Images/P0868.png
#   inflating: /kaggle/working/data/Images/P0869.png
#   inflating: /kaggle/working/data/Images/P0870.png
#   inflating: /kaggle/working/data/Images/P0871.png
#   inflating: /kaggle/working/data/Images/P0872.png
#   inflating: /kaggle/working/data/Images/P0873.png
#   inflating: /kaggle/working/data/Images/P0874.png
#   inflating: /kaggle/working/data/Images/P0875.png
#   inflating: /kaggle/working/data/Images/P0878.png
#   inflating: /kaggle/working/data/Images/P0879.png
#   inflating: /kaggle/working/data/Images/P0881.png
#   inflating: /kaggle/working/data/Images/P0883.png
#   inflating: /kaggle/working/data/Images/P0884.png
#   inflating: /kaggle/working/data/Images/P0885.png
#   inflating: /kaggle/working/data/Images/P0888.png
#   inflating: /kaggle/working/data/Images/P0890.png
#   inflating: /kaggle/working/data/Images/P0892.png
#   inflating: /kaggle/working/data/Images/P0893.png
#   inflating: /kaggle/working/data/Images/P0894.png
#   inflating: /kaggle/working/data/Images/P0895.png
#   inflating: /kaggle/working/data/Images/P0896.png
#   inflating: /kaggle/working/data/Images/P0898.png
#   inflating: /kaggle/working/data/Images/P0899.png
#   inflating: /kaggle/working/data/Images/P0900.png
#   inflating: /kaggle/working/data/Images/P0905.png
#   inflating: /kaggle/working/data/Images/P0906.png
#   inflating: /kaggle/working/data/Images/P0907.png
#   inflating: /kaggle/working/data/Images/P0908.png
#   inflating: /kaggle/working/data/Images/P0909.png
#   inflating: /kaggle/working/data/Images/P0911.png
#   inflating: /kaggle/working/data/Images/P0913.png
#   inflating: /kaggle/working/data/Images/P0914.png
#   inflating: /kaggle/working/data/Images/P0915.png
#   inflating: /kaggle/working/data/Images/P0918.png
#   inflating: /kaggle/working/data/Images/P0920.png
#   inflating: /kaggle/working/data/Images/P0921.png
#   inflating: /kaggle/working/data/Images/P0922.png
#   inflating: /kaggle/working/data/Images/P0925.png
#   inflating: /kaggle/working/data/Images/P0926.png
#   inflating: /kaggle/working/data/Images/P0928.png
#   inflating: /kaggle/working/data/Images/P0933.png
#   inflating: /kaggle/working/data/Images/P0934.png
#   inflating: /kaggle/working/data/Images/P0938.png
#   inflating: /kaggle/working/data/Images/P0940.png
#   inflating: /kaggle/working/data/Images/P0941.png
#   inflating: /kaggle/working/data/Images/P0944.png
#   inflating: /kaggle/working/data/Images/P0946.png
#   inflating: /kaggle/working/data/Images/P0947.png
#   inflating: /kaggle/working/data/Images/P0948.png
#   inflating: /kaggle/working/data/Images/P0950.png
#   inflating: /kaggle/working/data/Images/P0951.png
#   inflating: /kaggle/working/data/Images/P0952.png
#   inflating: /kaggle/working/data/Images/P0957.png
#   inflating: /kaggle/working/data/Images/P0960.png
#   inflating: /kaggle/working/data/Images/P0963.png
#   inflating: /kaggle/working/data/Images/P0966.png
#   inflating: /kaggle/working/data/Images/P0967.png
#   inflating: /kaggle/working/data/Images/P0972.png
#   inflating: /kaggle/working/data/Images/P0973.png
#   inflating: /kaggle/working/data/Images/P0975.png
#   inflating: /kaggle/working/data/Images/P0978.png
#   inflating: /kaggle/working/data/Images/P0979.png
#   inflating: /kaggle/working/data/Images/P0980.png
#   inflating: /kaggle/working/data/Images/P0981.png
#   inflating: /kaggle/working/data/Images/P0986.png
#   inflating: /kaggle/working/data/Images/P0987.png
#   inflating: /kaggle/working/data/Images/P0991.png
#   inflating: /kaggle/working/data/Images/P0993.png
#   inflating: /kaggle/working/data/Images/P0995.png
#   inflating: /kaggle/working/data/Images/P0999.png
#   inflating: /kaggle/working/data/Images/P1003.png
#   inflating: /kaggle/working/data/Images/P1006.png
#   inflating: /kaggle/working/data/Images/P1010.png
#   inflating: /kaggle/working/data/Images/P1012.png
#   inflating: /kaggle/working/data/Images/P1015.png
#   inflating: /kaggle/working/data/Images/P1016.png
#   inflating: /kaggle/working/data/Images/P1019.png
#   inflating: /kaggle/working/data/Images/P1020.png
#   inflating: /kaggle/working/data/Images/P1026.png
#   inflating: /kaggle/working/data/Images/P1027.png
#   inflating: /kaggle/working/data/Images/P1037.png
#   inflating: /kaggle/working/data/Images/P1043.png
#   inflating: /kaggle/working/data/Images/P1046.png
#   inflating: /kaggle/working/data/Images/P1047.png
#   inflating: /kaggle/working/data/Images/P1049.png
#   inflating: /kaggle/working/data/Images/P1052.png
#   inflating: /kaggle/working/data/Images/P1053.png
#   inflating: /kaggle/working/data/Images/P1054.png
#   inflating: /kaggle/working/data/Images/P1055.png
#   inflating: /kaggle/working/data/Images/P1057.png
#   inflating: /kaggle/working/data/Images/P1059.png
#   inflating: /kaggle/working/data/Images/P1060.png
#   inflating: /kaggle/working/data/Images/P1061.png
#   inflating: /kaggle/working/data/Images/P1062.png
#   inflating: /kaggle/working/data/Images/P1063.png
#   inflating: /kaggle/working/data/Images/P1067.png
#   inflating: /kaggle/working/data/Images/P1069.png
#   inflating: /kaggle/working/data/Images/P1070.png
#   inflating: /kaggle/working/data/Images/P1071.png
#   inflating: /kaggle/working/data/Images/P1073.png
#   inflating: /kaggle/working/data/Images/P1076.png
#   inflating: /kaggle/working/data/Images/P1077.png
#   inflating: /kaggle/working/data/Images/P1078.png
#   inflating: /kaggle/working/data/Images/P1079.png
#   inflating: /kaggle/working/data/Images/P1080.png
#   inflating: /kaggle/working/data/Images/P1084.png
#   inflating: /kaggle/working/data/Images/P1087.png
#   inflating: /kaggle/working/data/Images/P1089.png
#   inflating: /kaggle/working/data/Images/P1092.png
#   inflating: /kaggle/working/data/Images/P1094.png
#   inflating: /kaggle/working/data/Images/P1096.png
#   inflating: /kaggle/working/data/Images/P1098.png
#   inflating: /kaggle/working/data/Images/P1105.png
#   inflating: /kaggle/working/data/Images/P1107.png
#   inflating: /kaggle/working/data/Images/P1108.png
#   inflating: /kaggle/working/data/Images/P1109.png
#   inflating: /kaggle/working/data/Images/P1110.png
#   inflating: /kaggle/working/data/Images/P1113.png
#   inflating: /kaggle/working/data/Images/P1114.png
#   inflating: /kaggle/working/data/Images/P1116.png
#   inflating: /kaggle/working/data/Images/P1117.png
#   inflating: /kaggle/working/data/Images/P1118.png
#   inflating: /kaggle/working/data/Images/P1119.png
#   inflating: /kaggle/working/data/Images/P1121.png
#   inflating: /kaggle/working/data/Images/P1130.png
#   inflating: /kaggle/working/data/Images/P1131.png
#   inflating: /kaggle/working/data/Images/P1132.png
#   inflating: /kaggle/working/data/Images/P1139.png
#   inflating: /kaggle/working/data/Images/P1140.png
#   inflating: /kaggle/working/data/Images/P1141.png
#   inflating: /kaggle/working/data/Images/P1142.png
#   inflating: /kaggle/working/data/Images/P1144.png
#   inflating: /kaggle/working/data/Images/P1148.png
#   inflating: /kaggle/working/data/Images/P1150.png
#   inflating: /kaggle/working/data/Images/P1152.png
#   inflating: /kaggle/working/data/Images/P1155.png
#   inflating: /kaggle/working/data/Images/P1158.png
#   inflating: /kaggle/working/data/Images/P1159.png
#   inflating: /kaggle/working/data/Images/P1161.png
#   inflating: /kaggle/working/data/Images/P1164.png
#   inflating: /kaggle/working/data/Images/P1165.png
#   inflating: /kaggle/working/data/Images/P1166.png
#   inflating: /kaggle/working/data/Images/P1167.png
#   inflating: /kaggle/working/data/Images/P1168.png
#   inflating: /kaggle/working/data/Images/P1170.png
#   inflating: /kaggle/working/data/Images/P1171.png
#   inflating: /kaggle/working/data/Images/P1173.png
#   inflating: /kaggle/working/data/Images/P1174.png
#   inflating: /kaggle/working/data/Images/P1181.png
#   inflating: /kaggle/working/data/Images/P1182.png
#   inflating: /kaggle/working/data/Images/P1185.png
#   inflating: /kaggle/working/data/Images/P1186.png
#   inflating: /kaggle/working/data/Images/P1187.png
#   inflating: /kaggle/working/data/Images/P1191.png
#   inflating: /kaggle/working/data/Images/P1193.png
#   inflating: /kaggle/working/data/Images/P1198.png
#   inflating: /kaggle/working/data/Images/P1199.png
#   inflating: /kaggle/working/data/Images/P1200.png
#   inflating: /kaggle/working/data/Images/P1201.png
#   inflating: /kaggle/working/data/Images/P1205.png
#   inflating: /kaggle/working/data/Images/P1207.png
#   inflating: /kaggle/working/data/Images/P1208.png
#   inflating: /kaggle/working/data/Images/P1209.png
#   inflating: /kaggle/working/data/Images/P1211.png
#   inflating: /kaggle/working/data/Images/P1214.png
#   inflating: /kaggle/working/data/Images/P1216.png
#   inflating: /kaggle/working/data/Images/P1217.png
#   inflating: /kaggle/working/data/Images/P1221.png
#   inflating: /kaggle/working/data/Images/P1222.png
#   inflating: /kaggle/working/data/Images/P1223.png
#   inflating: /kaggle/working/data/Images/P1224.png
#   inflating: /kaggle/working/data/Images/P1228.png
#   inflating: /kaggle/working/data/Images/P1231.png
#   inflating: /kaggle/working/data/Images/P1232.png
#   inflating: /kaggle/working/data/Images/P1238.png
#   inflating: /kaggle/working/data/Images/P1239.png
#   inflating: /kaggle/working/data/Images/P1241.png
#   inflating: /kaggle/working/data/Images/P1243.png
#   inflating: /kaggle/working/data/Images/P1245.png
#   inflating: /kaggle/working/data/Images/P1247.png
#   inflating: /kaggle/working/data/Images/P1249.png
#   inflating: /kaggle/working/data/Images/P1250.png
#   inflating: /kaggle/working/data/Images/P1251.png
#   inflating: /kaggle/working/data/Images/P1255.png
#   inflating: /kaggle/working/data/Images/P1256.png
#   inflating: /kaggle/working/data/Images/P1258.png
#   inflating: /kaggle/working/data/Images/P1259.png
#   inflating: /kaggle/working/data/Images/P1260.png
#   inflating: /kaggle/working/data/Images/P1265.png
#   inflating: /kaggle/working/data/Images/P1267.png
#   inflating: /kaggle/working/data/Images/P1272.png
#   inflating: /kaggle/working/data/Images/P1274.png
#   inflating: /kaggle/working/data/Images/P1276.png
#   inflating: /kaggle/working/data/Images/P1277.png
#   inflating: /kaggle/working/data/Images/P1279.png
#   inflating: /kaggle/working/data/Images/P1281.png
#   inflating: /kaggle/working/data/Images/P1287.png
#   inflating: /kaggle/working/data/Images/P1288.png
#   inflating: /kaggle/working/data/Images/P1291.png
#   inflating: /kaggle/working/data/Images/P1292.png
#   inflating: /kaggle/working/data/Images/P1295.png
#   inflating: /kaggle/working/data/Images/P1297.png
#   inflating: /kaggle/working/data/Images/P1298.png
#   inflating: /kaggle/working/data/Images/P1299.png
#   inflating: /kaggle/working/data/Images/P1300.png
#   inflating: /kaggle/working/data/Images/P1305.png
#   inflating: /kaggle/working/data/Images/P1306.png
#   inflating: /kaggle/working/data/Images/P1307.png
#   inflating: /kaggle/working/data/Images/P1308.png
#   inflating: /kaggle/working/data/Images/P1309.png
#   inflating: /kaggle/working/data/Images/P1311.png
#   inflating: /kaggle/working/data/Images/P1317.png
#   inflating: /kaggle/working/data/Images/P1319.png
#   inflating: /kaggle/working/data/Images/P1321.png
#   inflating: /kaggle/working/data/Images/P1322.png
#   inflating: /kaggle/working/data/Images/P1325.png
#   inflating: /kaggle/working/data/Images/P1328.png
#   inflating: /kaggle/working/data/Images/P1329.png
#   inflating: /kaggle/working/data/Images/P1333.png
#   inflating: /kaggle/working/data/Images/P1336.png
#   inflating: /kaggle/working/data/Images/P1337.png
#   inflating: /kaggle/working/data/Images/P1338.png
#   inflating: /kaggle/working/data/Images/P1339.png
#   inflating: /kaggle/working/data/Images/P1340.png
#   inflating: /kaggle/working/data/Images/P1341.png
#   inflating: /kaggle/working/data/Images/P1343.png
#   inflating: /kaggle/working/data/Images/P1344.png
#   inflating: /kaggle/working/data/Images/P1350.png
#   inflating: /kaggle/working/data/Images/P1351.png
#   inflating: /kaggle/working/data/Images/P1352.png
#   inflating: /kaggle/working/data/Images/P1353.png
#   inflating: /kaggle/working/data/Images/P1354.png
#   inflating: /kaggle/working/data/Images/P1357.png
#   inflating: /kaggle/working/data/Images/P1358.png
#   inflating: /kaggle/working/data/Images/P1359.png
#   inflating: /kaggle/working/data/Images/P1360.png
#   inflating: /kaggle/working/data/Images/P1361.png
#   inflating: /kaggle/working/data/Images/P1364.png
#   inflating: /kaggle/working/data/Images/P1365.png
#   inflating: /kaggle/working/data/Images/P1366.png
#   inflating: /kaggle/working/data/Images/P1368.png
#   inflating: /kaggle/working/data/Images/P1369.png
#   inflating: /kaggle/working/data/Images/P1374.png
#   inflating: /kaggle/working/data/Images/P1375.png
#   inflating: /kaggle/working/data/Images/P1382.png
#   inflating: /kaggle/working/data/Images/P1387.png
#   inflating: /kaggle/working/data/Images/P1388.png
#   inflating: /kaggle/working/data/Images/P1389.png
#   inflating: /kaggle/working/data/Images/P1391.png
#   inflating: /kaggle/working/data/Images/P1392.png
#   inflating: /kaggle/working/data/Images/P1393.png
#   inflating: /kaggle/working/data/Images/P1394.png
#   inflating: /kaggle/working/data/Images/P1395.png
#   inflating: /kaggle/working/data/Images/P1399.png
#   inflating: /kaggle/working/data/Images/P1401.png
#   inflating: /kaggle/working/data/Images/P1403.png
#   inflating: /kaggle/working/data/Images/P1408.png
#   inflating: /kaggle/working/data/Images/P1412.png
#   inflating: /kaggle/working/data/Images/P1413.png
#   inflating: /kaggle/working/data/Images/P1414.png
#   inflating: /kaggle/working/data/Images/P1416.png
#   inflating: /kaggle/working/data/Images/P1418.png
#   inflating: /kaggle/working/data/Images/P1419.png
#   inflating: /kaggle/working/data/Images/P1420.png
#   inflating: /kaggle/working/data/Images/P1421.png
#   inflating: /kaggle/working/data/Images/P1426.png
#   inflating: /kaggle/working/data/Images/P1427.png
#   inflating: /kaggle/working/data/Images/P1428.png
#   inflating: /kaggle/working/data/Images/P1431.png
#   inflating: /kaggle/working/data/Images/P1433.png
#   inflating: /kaggle/working/data/Images/P1437.png
#   inflating: /kaggle/working/data/Images/P1438.png
#   inflating: /kaggle/working/data/Images/P1439.png
#   inflating: /kaggle/working/data/Images/P1443.png
#   inflating: /kaggle/working/data/Images/P1444.png
#   inflating: /kaggle/working/data/Images/P1445.png
#   inflating: /kaggle/working/data/Images/P1446.png
#   inflating: /kaggle/working/data/Images/P1449.png
#   inflating: /kaggle/working/data/Images/P1450.png
#   inflating: /kaggle/working/data/Images/P1451.png
#   inflating: /kaggle/working/data/Images/P1453.png
#   inflating: /kaggle/working/data/Images/P1455.png
#   inflating: /kaggle/working/data/Images/P1457.png
#   inflating: /kaggle/working/data/Images/P1458.png
#   inflating: /kaggle/working/data/Images/P1459.png
#   inflating: /kaggle/working/data/Images/P1460.png
#   inflating: /kaggle/working/data/Images/P1462.png
#   inflating: /kaggle/working/data/Images/P1464.png
#   inflating: /kaggle/working/data/Images/P1465.png
#   inflating: /kaggle/working/data/Images/P1466.png
#   inflating: /kaggle/working/data/Images/P1467.png
#   inflating: /kaggle/working/data/Images/P1469.png
#   inflating: /kaggle/working/data/Images/P1470.png
#   inflating: /kaggle/working/data/Images/P1475.png
#   inflating: /kaggle/working/data/Images/P1479.png
#   inflating: /kaggle/working/data/Images/P1480.png
#   inflating: /kaggle/working/data/Images/P1481.png
#   inflating: /kaggle/working/data/Images/P1482.png
#   inflating: /kaggle/working/data/Images/P1484.png
#   inflating: /kaggle/working/data/Images/P1486.png
#   inflating: /kaggle/working/data/Images/P1487.png
#   inflating: /kaggle/working/data/Images/P1489.png
#   inflating: /kaggle/working/data/Images/P1493.png
#   inflating: /kaggle/working/data/Images/P1495.png
#   inflating: /kaggle/working/data/Images/P1497.png
#   inflating: /kaggle/working/data/Images/P1498.png
#   inflating: /kaggle/working/data/Images/P1499.png
#   inflating: /kaggle/working/data/Images/P1501.png
#   inflating: /kaggle/working/data/Images/P1502.png
#   inflating: /kaggle/working/data/Images/P1505.png
#   inflating: /kaggle/working/data/Images/P1507.png
#   inflating: /kaggle/working/data/Images/P1509.png
#   inflating: /kaggle/working/data/Images/P1514.png
#   inflating: /kaggle/working/data/Images/P1515.png
#   inflating: /kaggle/working/data/Images/P1517.png
#   inflating: /kaggle/working/data/Images/P1519.png
#   inflating: /kaggle/working/data/Images/P1521.png
#   inflating: /kaggle/working/data/Images/P1522.png
#   inflating: /kaggle/working/data/Images/P1524.png
#   inflating: /kaggle/working/data/Images/P1526.png
#   inflating: /kaggle/working/data/Images/P1531.png
#   inflating: /kaggle/working/data/Images/P1533.png
#   inflating: /kaggle/working/data/Images/P1534.png
#   inflating: /kaggle/working/data/Images/P1535.png
#   inflating: /kaggle/working/data/Images/P1537.png
#   inflating: /kaggle/working/data/Images/P1539.png
#   inflating: /kaggle/working/data/Images/P1540.png
#   inflating: /kaggle/working/data/Images/P1545.png
#   inflating: /kaggle/working/data/Images/P1550.png
#   inflating: /kaggle/working/data/Images/P1551.png
#   inflating: /kaggle/working/data/Images/P1552.png
#   inflating: /kaggle/working/data/Images/P1554.png
#   inflating: /kaggle/working/data/Images/P1555.png
#   inflating: /kaggle/working/data/Images/P1556.png
#   inflating: /kaggle/working/data/Images/P1558.png
#   inflating: /kaggle/working/data/Images/P1562.png
#   inflating: /kaggle/working/data/Images/P1563.png
#   inflating: /kaggle/working/data/Images/P1565.png
#   inflating: /kaggle/working/data/Images/P1571.png
#   inflating: /kaggle/working/data/Images/P1574.png
#   inflating: /kaggle/working/data/Images/P1580.png
#   inflating: /kaggle/working/data/Images/P1582.png
#   inflating: /kaggle/working/data/Images/P1585.png
#   inflating: /kaggle/working/data/Images/P1587.png
#   inflating: /kaggle/working/data/Images/P1589.png
#   inflating: /kaggle/working/data/Images/P1591.png
#   inflating: /kaggle/working/data/Images/P1594.png
#   inflating: /kaggle/working/data/Images/P1597.png
#   inflating: /kaggle/working/data/Images/P1599.png
#   inflating: /kaggle/working/data/Images/P1600.png
#   inflating: /kaggle/working/data/Images/P1602.png
#   inflating: /kaggle/working/data/Images/P1606.png
#   inflating: /kaggle/working/data/Images/P1607.png
#   inflating: /kaggle/working/data/Images/P1608.png
#   inflating: /kaggle/working/data/Images/P1609.png
#   inflating: /kaggle/working/data/Images/P1614.png
#   inflating: /kaggle/working/data/Images/P1615.png
#   inflating: /kaggle/working/data/Images/P1616.png
#   inflating: /kaggle/working/data/Images/P1617.png
#   inflating: /kaggle/working/data/Images/P1618.png
#   inflating: /kaggle/working/data/Images/P1620.png
#   inflating: /kaggle/working/data/Images/P1631.png
#   inflating: /kaggle/working/data/Images/P1632.png
#   inflating: /kaggle/working/data/Images/P1633.png
#   inflating: /kaggle/working/data/Images/P1634.png
#   inflating: /kaggle/working/data/Images/P1636.png
#   inflating: /kaggle/working/data/Images/P1638.png
#   inflating: /kaggle/working/data/Images/P1639.png
#   inflating: /kaggle/working/data/Images/P1640.png
#   inflating: /kaggle/working/data/Images/P1641.png
#   inflating: /kaggle/working/data/Images/P1645.png
#   inflating: /kaggle/working/data/Images/P1646.png
#   inflating: /kaggle/working/data/Images/P1649.png
#   inflating: /kaggle/working/data/Images/P1652.png
#   inflating: /kaggle/working/data/Images/P1653.png
#   inflating: /kaggle/working/data/Images/P1656.png
#   inflating: /kaggle/working/data/Images/P1658.png
#   inflating: /kaggle/working/data/Images/P1659.png
#   inflating: /kaggle/working/data/Images/P1660.png
#   inflating: /kaggle/working/data/Images/P1661.png
#   inflating: /kaggle/working/data/Images/P1662.png
#   inflating: /kaggle/working/data/Images/P1669.png
#   inflating: /kaggle/working/data/Images/P1670.png
#   inflating: /kaggle/working/data/Images/P1673.png
#   inflating: /kaggle/working/data/Images/P1674.png
#   inflating: /kaggle/working/data/Images/P1675.png
#   inflating: /kaggle/working/data/Images/P1676.png
#   inflating: /kaggle/working/data/Images/P1680.png
#   inflating: /kaggle/working/data/Images/P1682.png
#   inflating: /kaggle/working/data/Images/P1683.png
#   inflating: /kaggle/working/data/Images/P1685.png
#   inflating: /kaggle/working/data/Images/P1686.png
#   inflating: /kaggle/working/data/Images/P1688.png
#   inflating: /kaggle/working/data/Images/P1689.png
#   inflating: /kaggle/working/data/Images/P1691.png
#   inflating: /kaggle/working/data/Images/P1696.png
#   inflating: /kaggle/working/data/Images/P1697.png
#   inflating: /kaggle/working/data/Images/P1698.png
#   inflating: /kaggle/working/data/Images/P1702.png
#   inflating: /kaggle/working/data/Images/P1703.png
#   inflating: /kaggle/working/data/Images/P1704.png
#   inflating: /kaggle/working/data/Images/P1705.png
#   inflating: /kaggle/working/data/Images/P1707.png
#   inflating: /kaggle/working/data/Images/P1708.png
#   inflating: /kaggle/working/data/Images/P1709.png
#   inflating: /kaggle/working/data/Images/P1714.png
#   inflating: /kaggle/working/data/Images/P1717.png
#   inflating: /kaggle/working/data/Images/P1719.png
#   inflating: /kaggle/working/data/Images/P1724.png
#   inflating: /kaggle/working/data/Images/P1725.png
#   inflating: /kaggle/working/data/Images/P1726.png
#   inflating: /kaggle/working/data/Images/P1727.png
#   inflating: /kaggle/working/data/Images/P1730.png
#   inflating: /kaggle/working/data/Images/P1736.png
#   inflating: /kaggle/working/data/Images/P1739.png
#   inflating: /kaggle/working/data/Images/P1740.png
#   inflating: /kaggle/working/data/Images/P1741.png
#   inflating: /kaggle/working/data/Images/P1743.png
#   inflating: /kaggle/working/data/Images/P1744.png
#   inflating: /kaggle/working/data/Images/P1745.png
#   inflating: /kaggle/working/data/Images/P1746.png
#   inflating: /kaggle/working/data/Images/P1747.png
#   inflating: /kaggle/working/data/Images/P1748.png
#   inflating: /kaggle/working/data/Images/P1753.png
#   inflating: /kaggle/working/data/Images/P1756.png
#   inflating: /kaggle/working/data/Images/P1757.png
#   inflating: /kaggle/working/data/Images/P1758.png
#   inflating: /kaggle/working/data/Images/P1765.png
#   inflating: /kaggle/working/data/Images/P1768.png
#   inflating: /kaggle/working/data/Images/P1773.png
#   inflating: /kaggle/working/data/Images/P1775.png
#   inflating: /kaggle/working/data/Images/P1776.png
#   inflating: /kaggle/working/data/Images/P1778.png
#   inflating: /kaggle/working/data/Images/P1779.png
#   inflating: /kaggle/working/data/Images/P1780.png
#   inflating: /kaggle/working/data/Images/P1783.png
#   inflating: /kaggle/working/data/Images/P1784.png
#   inflating: /kaggle/working/data/Images/P1785.png
#   inflating: /kaggle/working/data/Images/P1788.png
#   inflating: /kaggle/working/data/Images/P1789.png
#   inflating: /kaggle/working/data/Images/P1790.png
#   inflating: /kaggle/working/data/Images/P1791.png
#   inflating: /kaggle/working/data/Images/P1793.png
#   inflating: /kaggle/working/data/Images/P1794.png
#   inflating: /kaggle/working/data/Images/P1795.png
#   inflating: /kaggle/working/data/Images/P1799.png
#   inflating: /kaggle/working/data/Images/P1801.png
#   inflating: /kaggle/working/data/Images/P1804.png
#   inflating: /kaggle/working/data/Images/P1805.png
#   inflating: /kaggle/working/data/Images/P1807.png
#   inflating: /kaggle/working/data/Images/P1808.png
#   inflating: /kaggle/working/data/Images/P1812.png
#   inflating: /kaggle/working/data/Images/P1816.png
#   inflating: /kaggle/working/data/Images/P1818.png
#   inflating: /kaggle/working/data/Images/P1822.png
#   inflating: /kaggle/working/data/Images/P1823.png
#   inflating: /kaggle/working/data/Images/P1827.png
#   inflating: /kaggle/working/data/Images/P1832.png
#   inflating: /kaggle/working/data/Images/P1833.png
#   inflating: /kaggle/working/data/Images/P1837.png
#   inflating: /kaggle/working/data/Images/P1839.png
# ...
#   inflating: /kaggle/working/data/labelTxt/P2240.txt
#   inflating: /kaggle/working/data/labelTxt/P2243.txt
#   inflating: /kaggle/working/data/labelTxt/P2244.txt
#   inflating: /kaggle/working/data/labelTxt/P2245.txt
#   inflating: /kaggle/working/data/labelTxt/P2247.txt
#   inflating: /kaggle/working/data/labelTxt/P2248.txt
#   inflating: /kaggle/working/data/labelTxt/P2249.txt
#   inflating: /kaggle/working/data/labelTxt/P2250.txt
#   inflating: /kaggle/working/data/labelTxt/P2251.txt
#   inflating: /kaggle/working/data/labelTxt/P2253.txt
#   inflating: /kaggle/working/data/labelTxt/P2257.txt
#   inflating: /kaggle/working/data/labelTxt/P2258.txt
#   inflating: /kaggle/working/data/labelTxt/P2259.txt
#   inflating: /kaggle/working/data/labelTxt/P2260.txt
#   inflating: /kaggle/working/data/labelTxt/P2262.txt
#   inflating: /kaggle/working/data/labelTxt/P2264.txt
#   inflating: /kaggle/working/data/labelTxt/P2266.txt
#   inflating: /kaggle/working/data/labelTxt/P2269.txt
#   inflating: /kaggle/working/data/labelTxt/P2270.txt
#   inflating: /kaggle/working/data/labelTxt/P2275.txt
#   inflating: /kaggle/working/data/labelTxt/P2278.txt
#   inflating: /kaggle/working/data/labelTxt/P2279.txt
#   inflating: /kaggle/working/data/labelTxt/P2280.txt
#   inflating: /kaggle/working/data/labelTxt/P2281.txt
#   inflating: /kaggle/working/data/labelTxt/P2282.txt
#   inflating: /kaggle/working/data/labelTxt/P2283.txt
#   inflating: /kaggle/working/data/labelTxt/P2287.txt
#   inflating: /kaggle/working/data/labelTxt/P2288.txt
#   inflating: /kaggle/working/data/labelTxt/P2289.txt
#   inflating: /kaggle/working/data/labelTxt/P2301.txt
#   inflating: /kaggle/working/data/labelTxt/P2302.txt
#   inflating: /kaggle/working/data/labelTxt/P2303.txt
#   inflating: /kaggle/working/data/labelTxt/P2304.txt
#   inflating: /kaggle/working/data/labelTxt/P2305.txt
#   inflating: /kaggle/working/data/labelTxt/P2306.txt
#   inflating: /kaggle/working/data/labelTxt/P2309.txt
#   inflating: /kaggle/working/data/labelTxt/P2311.txt
#   inflating: /kaggle/working/data/labelTxt/P2313.txt
#   inflating: /kaggle/working/data/labelTxt/P2319.txt
#   inflating: /kaggle/working/data/labelTxt/P2321.txt
#   inflating: /kaggle/working/data/labelTxt/P2324.txt
#   inflating: /kaggle/working/data/labelTxt/P2326.txt
#   inflating: /kaggle/working/data/labelTxt/P2327.txt
#   inflating: /kaggle/working/data/labelTxt/P2328.txt
#   inflating: /kaggle/working/data/labelTxt/P2332.txt
#   inflating: /kaggle/working/data/labelTxt/P2334.txt
#   inflating: /kaggle/working/data/labelTxt/P2335.txt
#   inflating: /kaggle/working/data/labelTxt/P2339.txt
#   inflating: /kaggle/working/data/labelTxt/P2343.txt
#   inflating: /kaggle/working/data/labelTxt/P2344.txt
#   inflating: /kaggle/working/data/labelTxt/P2346.txt
#   inflating: /kaggle/working/data/labelTxt/P2348.txt
#   inflating: /kaggle/working/data/labelTxt/P2349.txt
#   inflating: /kaggle/working/data/labelTxt/P2352.txt
#   inflating: /kaggle/working/data/labelTxt/P2354.txt
#   inflating: /kaggle/working/data/labelTxt/P2355.txt
#   inflating: /kaggle/working/data/labelTxt/P2356.txt
#   inflating: /kaggle/working/data/labelTxt/P2359.txt
#   inflating: /kaggle/working/data/labelTxt/P2362.txt
#   inflating: /kaggle/working/data/labelTxt/P2364.txt
#   inflating: /kaggle/working/data/labelTxt/P2368.txt
#   inflating: /kaggle/working/data/labelTxt/P2370.txt
#   inflating: /kaggle/working/data/labelTxt/P2371.txt
#   inflating: /kaggle/working/data/labelTxt/P2373.txt
#   inflating: /kaggle/working/data/labelTxt/P2377.txt
#   inflating: /kaggle/working/data/labelTxt/P2379.txt
#   inflating: /kaggle/working/data/labelTxt/P2380.txt
#   inflating: /kaggle/working/data/labelTxt/P2381.txt
#   inflating: /kaggle/working/data/labelTxt/P2382.txt
#   inflating: /kaggle/working/data/labelTxt/P2387.txt
#   inflating: /kaggle/working/data/labelTxt/P2388.txt
#   inflating: /kaggle/working/data/labelTxt/P2389.txt
#   inflating: /kaggle/working/data/labelTxt/P2390.txt
#   inflating: /kaggle/working/data/labelTxt/P2392.txt
#   inflating: /kaggle/working/data/labelTxt/P2395.txt
#   inflating: /kaggle/working/data/labelTxt/P2396.txt
#   inflating: /kaggle/working/data/labelTxt/P2397.txt
#   inflating: /kaggle/working/data/labelTxt/P2401.txt
#   inflating: /kaggle/working/data/labelTxt/P2403.txt
#   inflating: /kaggle/working/data/labelTxt/P2409.txt
#   inflating: /kaggle/working/data/labelTxt/P2411.txt
#   inflating: /kaggle/working/data/labelTxt/P2415.txt
#   inflating: /kaggle/working/data/labelTxt/P2416.txt
#   inflating: /kaggle/working/data/labelTxt/P2417.txt
#   inflating: /kaggle/working/data/labelTxt/P2418.txt
#   inflating: /kaggle/working/data/labelTxt/P2419.txt
#   inflating: /kaggle/working/data/labelTxt/P2421.txt
#   inflating: /kaggle/working/data/labelTxt/P2422.txt
#   inflating: /kaggle/working/data/labelTxt/P2423.txt
#   inflating: /kaggle/working/data/labelTxt/P2426.txt
#   inflating: /kaggle/working/data/labelTxt/P2427.txt
#   inflating: /kaggle/working/data/labelTxt/P2428.txt
#   inflating: /kaggle/working/data/labelTxt/P2430.txt
#   inflating: /kaggle/working/data/labelTxt/P2432.txt
#   inflating: /kaggle/working/data/labelTxt/P2433.txt
#   inflating: /kaggle/working/data/labelTxt/P2435.txt
#   inflating: /kaggle/working/data/labelTxt/P2436.txt
#   inflating: /kaggle/working/data/labelTxt/P2437.txt
#   inflating: /kaggle/working/data/labelTxt/P2438.txt
#   inflating: /kaggle/working/data/labelTxt/P2442.txt
#   inflating: /kaggle/working/data/labelTxt/P2444.txt
#   inflating: /kaggle/working/data/labelTxt/P2452.txt
#   inflating: /kaggle/working/data/labelTxt/P2453.txt
#   inflating: /kaggle/working/data/labelTxt/P2454.txt
#   inflating: /kaggle/working/data/labelTxt/P2456.txt
#   inflating: /kaggle/working/data/labelTxt/P2457.txt
#   inflating: /kaggle/working/data/labelTxt/P2458.txt
#   inflating: /kaggle/working/data/labelTxt/P2460.txt
#   inflating: /kaggle/working/data/labelTxt/P2464.txt
#   inflating: /kaggle/working/data/labelTxt/P2465.txt
#   inflating: /kaggle/working/data/labelTxt/P2466.txt
#   inflating: /kaggle/working/data/labelTxt/P2467.txt
#   inflating: /kaggle/working/data/labelTxt/P2468.txt
#   inflating: /kaggle/working/data/labelTxt/P2469.txt
#   inflating: /kaggle/working/data/labelTxt/P2470.txt
#   inflating: /kaggle/working/data/labelTxt/P2471.txt
#   inflating: /kaggle/working/data/labelTxt/P2472.txt
#   inflating: /kaggle/working/data/labelTxt/P2475.txt
#   inflating: /kaggle/working/data/labelTxt/P2476.txt
#   inflating: /kaggle/working/data/labelTxt/P2479.txt
#   inflating: /kaggle/working/data/labelTxt/P2482.txt
#   inflating: /kaggle/working/data/labelTxt/P2483.txt
#   inflating: /kaggle/working/data/labelTxt/P2485.txt
#   inflating: /kaggle/working/data/labelTxt/P2490.txt
#   inflating: /kaggle/working/data/labelTxt/P2491.txt
#   inflating: /kaggle/working/data/labelTxt/P2492.txt
#   inflating: /kaggle/working/data/labelTxt/P2494.txt
#   inflating: /kaggle/working/data/labelTxt/P2495.txt
#   inflating: /kaggle/working/data/labelTxt/P2496.txt
#   inflating: /kaggle/working/data/labelTxt/P2497.txt
#   inflating: /kaggle/working/data/labelTxt/P2501.txt
#   inflating: /kaggle/working/data/labelTxt/P2503.txt
#   inflating: /kaggle/working/data/labelTxt/P2505.txt
#   inflating: /kaggle/working/data/labelTxt/P2506.txt
#   inflating: /kaggle/working/data/labelTxt/P2507.txt
#   inflating: /kaggle/working/data/labelTxt/P2509.txt
#   inflating: /kaggle/working/data/labelTxt/P2512.txt
#   inflating: /kaggle/working/data/labelTxt/P2513.txt
#   inflating: /kaggle/working/data/labelTxt/P2514.txt
#   inflating: /kaggle/working/data/labelTxt/P2516.txt
#   inflating: /kaggle/working/data/labelTxt/P2517.txt
#   inflating: /kaggle/working/data/labelTxt/P2518.txt
#   inflating: /kaggle/working/data/labelTxt/P2519.txt
#   inflating: /kaggle/working/data/labelTxt/P2520.txt
#   inflating: /kaggle/working/data/labelTxt/P2522.txt
#   inflating: /kaggle/working/data/labelTxt/P2523.txt
#   inflating: /kaggle/working/data/labelTxt/P2527.txt
#   inflating: /kaggle/working/data/labelTxt/P2528.txt
#   inflating: /kaggle/working/data/labelTxt/P2529.txt
#   inflating: /kaggle/working/data/labelTxt/P2531.txt
#   inflating: /kaggle/working/data/labelTxt/P2532.txt
#   inflating: /kaggle/working/data/labelTxt/P2533.txt
#   inflating: /kaggle/working/data/labelTxt/P2534.txt
#   inflating: /kaggle/working/data/labelTxt/P2536.txt
#   inflating: /kaggle/working/data/labelTxt/P2538.txt
#   inflating: /kaggle/working/data/labelTxt/P2543.txt
#   inflating: /kaggle/working/data/labelTxt/P2545.txt
#   inflating: /kaggle/working/data/labelTxt/P2548.txt
#   inflating: /kaggle/working/data/labelTxt/P2550.txt
#   inflating: /kaggle/working/data/labelTxt/P2551.txt
#   inflating: /kaggle/working/data/labelTxt/P2552.txt
#   inflating: /kaggle/working/data/labelTxt/P2553.txt
#   inflating: /kaggle/working/data/labelTxt/P2554.txt
#   inflating: /kaggle/working/data/labelTxt/P2557.txt
#   inflating: /kaggle/working/data/labelTxt/P2558.txt
#   inflating: /kaggle/working/data/labelTxt/P2560.txt
#   inflating: /kaggle/working/data/labelTxt/P2561.txt
#   inflating: /kaggle/working/data/labelTxt/P2565.txt
#   inflating: /kaggle/working/data/labelTxt/P2566.txt
#   inflating: /kaggle/working/data/labelTxt/P2569.txt
#   inflating: /kaggle/working/data/labelTxt/P2572.txt
#   inflating: /kaggle/working/data/labelTxt/P2576.txt
#   inflating: /kaggle/working/data/labelTxt/P2578.txt
#   inflating: /kaggle/working/data/labelTxt/P2579.txt
#   inflating: /kaggle/working/data/labelTxt/P2584.txt
#   inflating: /kaggle/working/data/labelTxt/P2585.txt
#   inflating: /kaggle/working/data/labelTxt/P2590.txt
#   inflating: /kaggle/working/data/labelTxt/P2591.txt
#   inflating: /kaggle/working/data/labelTxt/P2594.txt
#   inflating: /kaggle/working/data/labelTxt/P2597.txt
#   inflating: /kaggle/working/data/labelTxt/P2600.txt
#   inflating: /kaggle/working/data/labelTxt/P2601.txt
#   inflating: /kaggle/working/data/labelTxt/P2604.txt
#   inflating: /kaggle/working/data/labelTxt/P2605.txt
#   inflating: /kaggle/working/data/labelTxt/P2606.txt
#   inflating: /kaggle/working/data/labelTxt/P2609.txt
#   inflating: /kaggle/working/data/labelTxt/P2611.txt
#   inflating: /kaggle/working/data/labelTxt/P2612.txt
#   inflating: /kaggle/working/data/labelTxt/P2613.txt
#   inflating: /kaggle/working/data/labelTxt/P2614.txt
#   inflating: /kaggle/working/data/labelTxt/P2615.txt
#   inflating: /kaggle/working/data/labelTxt/P2616.txt
#   inflating: /kaggle/working/data/labelTxt/P2618.txt
#   inflating: /kaggle/working/data/labelTxt/P2621.txt
#   inflating: /kaggle/working/data/labelTxt/P2622.txt
#   inflating: /kaggle/working/data/labelTxt/P2626.txt
#   inflating: /kaggle/working/data/labelTxt/P2627.txt
#   inflating: /kaggle/working/data/labelTxt/P2628.txt
#   inflating: /kaggle/working/data/labelTxt/P2629.txt
#   inflating: /kaggle/working/data/labelTxt/P2631.txt
#   inflating: /kaggle/working/data/labelTxt/P2632.txt
#   inflating: /kaggle/working/data/labelTxt/P2634.txt
#   inflating: /kaggle/working/data/labelTxt/P2637.txt
#   inflating: /kaggle/working/data/labelTxt/P2638.txt
#   inflating: /kaggle/working/data/labelTxt/P2639.txt
#   inflating: /kaggle/working/data/labelTxt/P2641.txt
#   inflating: /kaggle/working/data/labelTxt/P2642.txt
#   inflating: /kaggle/working/data/labelTxt/P2644.txt
#   inflating: /kaggle/working/data/labelTxt/P2646.txt
#   inflating: /kaggle/working/data/labelTxt/P2650.txt
#   inflating: /kaggle/working/data/labelTxt/P2651.txt
#   inflating: /kaggle/working/data/labelTxt/P2653.txt
#   inflating: /kaggle/working/data/labelTxt/P2655.txt
#   inflating: /kaggle/working/data/labelTxt/P2656.txt
#   inflating: /kaggle/working/data/labelTxt/P2657.txt
#   inflating: /kaggle/working/data/labelTxt/P2659.txt
#   inflating: /kaggle/working/data/labelTxt/P2662.txt
#   inflating: /kaggle/working/data/labelTxt/P2663.txt
#   inflating: /kaggle/working/data/labelTxt/P2664.txt
#   inflating: /kaggle/working/data/labelTxt/P2665.txt
#   inflating: /kaggle/working/data/labelTxt/P2668.txt
#   inflating: /kaggle/working/data/labelTxt/P2669.txt
#   inflating: /kaggle/working/data/labelTxt/P2670.txt
#   inflating: /kaggle/working/data/labelTxt/P2671.txt
#   inflating: /kaggle/working/data/labelTxt/P2672.txt
#   inflating: /kaggle/working/data/labelTxt/P2673.txt
#   inflating: /kaggle/working/data/labelTxt/P2674.txt
#   inflating: /kaggle/working/data/labelTxt/P2676.txt
#   inflating: /kaggle/working/data/labelTxt/P2680.txt
#   inflating: /kaggle/working/data/labelTxt/P2681.txt
#   inflating: /kaggle/working/data/labelTxt/P2682.txt
#   inflating: /kaggle/working/data/labelTxt/P2685.txt
#   inflating: /kaggle/working/data/labelTxt/P2686.txt
#   inflating: /kaggle/working/data/labelTxt/P2687.txt
#   inflating: /kaggle/working/data/labelTxt/P2690.txt
#   inflating: /kaggle/working/data/labelTxt/P2691.txt
#   inflating: /kaggle/working/data/labelTxt/P2692.txt
#   inflating: /kaggle/working/data/labelTxt/P2693.txt
#   inflating: /kaggle/working/data/labelTxt/P2696.txt
#   inflating: /kaggle/working/data/labelTxt/P2700.txt
#   inflating: /kaggle/working/data/labelTxt/P2702.txt
#   inflating: /kaggle/working/data/labelTxt/P2704.txt
#   inflating: /kaggle/working/data/labelTxt/P2705.txt
#   inflating: /kaggle/working/data/labelTxt/P2706.txt
#   inflating: /kaggle/working/data/labelTxt/P2708.txt
#   inflating: /kaggle/working/data/labelTxt/P2710.txt
#   inflating: /kaggle/working/data/labelTxt/P2712.txt
#   inflating: /kaggle/working/data/labelTxt/P2716.txt
#   inflating: /kaggle/working/data/labelTxt/P2719.txt
#   inflating: /kaggle/working/data/labelTxt/P2720.txt
#   inflating: /kaggle/working/data/labelTxt/P2725.txt
#   inflating: /kaggle/working/data/labelTxt/P2727.txt
#   inflating: /kaggle/working/data/labelTxt/P2728.txt
#   inflating: /kaggle/working/data/labelTxt/P2729.txt
#   inflating: /kaggle/working/data/labelTxt/P2730.txt
#   inflating: /kaggle/working/data/labelTxt/P2731.txt
#   inflating: /kaggle/working/data/labelTxt/P2732.txt
#   inflating: /kaggle/working/data/labelTxt/P2734.txt
#   inflating: /kaggle/working/data/labelTxt/P2735.txt
#   inflating: /kaggle/working/data/labelTxt/P2739.txt
#   inflating: /kaggle/working/data/labelTxt/P2740.txt
#   inflating: /kaggle/working/data/labelTxt/P2741.txt
#   inflating: /kaggle/working/data/labelTxt/P2742.txt
#   inflating: /kaggle/working/data/labelTxt/P2743.txt
#   inflating: /kaggle/working/data/labelTxt/P2746.txt
#   inflating: /kaggle/working/data/labelTxt/P2747.txt
#   inflating: /kaggle/working/data/labelTxt/P2748.txt
#   inflating: /kaggle/working/data/labelTxt/P2750.txt
#   inflating: /kaggle/working/data/labelTxt/P2751.txt
#   inflating: /kaggle/working/data/labelTxt/P2753.txt
#   inflating: /kaggle/working/data/labelTxt/P2755.txt
#   inflating: /kaggle/working/data/labelTxt/P2756.txt
#   inflating: /kaggle/working/data/labelTxt/P2759.txt
#   inflating: /kaggle/working/data/labelTxt/P2761.txt
#   inflating: /kaggle/working/data/labelTxt/P2764.txt
#   inflating: /kaggle/working/data/labelTxt/P2769.txt
#   inflating: /kaggle/working/data/labelTxt/P2770.txt
#   inflating: /kaggle/working/data/labelTxt/P2775.txt
#   inflating: /kaggle/working/data/labelTxt/P2777.txt
#   inflating: /kaggle/working/data/labelTxt/P2783.txt
#   inflating: /kaggle/working/data/labelTxt/P2787.txt
#   inflating: /kaggle/working/data/labelTxt/P2788.txt
#   inflating: /kaggle/working/data/labelTxt/P2790.txt
#   inflating: /kaggle/working/data/labelTxt/P2792.txt
#   inflating: /kaggle/working/data/labelTxt/P2793.txt
#   inflating: /kaggle/working/data/labelTxt/P2797.txt
#   inflating: /kaggle/working/data/labelTxt/P2800.txt
#   inflating: /kaggle/working/data/labelTxt/P2801.txt
#   inflating: /kaggle/working/data/labelTxt/P2804.txt
#   inflating: /kaggle/working/data/labelTxt/P2805.txt

# %%
cd /kaggle/working
# Out:
# /kaggle/working

# %%
import os, random, math, json, gc
from pathlib import Path
from collections import defaultdict
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import torchvision
from torchvision.transforms import functional as TF
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.ops import roi_align, nms, box_iou
from torchvision.models.detection.image_list import ImageList  # Add this import

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Torch:", torch.__version__, "TorchVision:", torchvision.__version__, "Device:", DEVICE)
print("Number of GPUs:", torch.cuda.device_count())

DOTA_ROOT = "/kaggle/working/data"
MEAN = [0.485, 0.456, 0.406]
STD = [0.229, 0.224, 0.225]
IMG_MIN, IMG_MAX = 800, 1333
TARGET_SIZE = (800, 800)

def set_seed(s=42):
    random.seed(s); np.random.seed(s); torch.manual_seed(s); torch.cuda.manual_seed_all(s)
set_seed(42)

# Unchanged utility functions: resize_keep_ratio, to_tensor_norm, obb_to_hbb, DOTAIndex, EpisodeSampler
def resize_keep_ratio(img, min_side=IMG_MIN, max_side=IMG_MAX, target_size=TARGET_SIZE):
    w, h = img.size
    scale = min(min_side / min(h, w), max_side / max(h, w))
    new_w, new_h = int(w * scale), int(h * scale)
    img_r = img.resize((new_w, new_h), Image.BILINEAR)
    pad_w = target_size[1] - new_w
    pad_h = target_size[0] - new_h
    pad_left = pad_w // 2
    pad_top = pad_h // 2
    img_padded = Image.new("RGB", target_size, (0, 0, 0))
    img_padded.paste(img_r, (pad_left, pad_top))
    return img_padded, scale, (pad_left, pad_top)

def to_tensor_norm(img):
    t = TF.to_tensor(img)
    t = TF.normalize(t, mean=MEAN, std=STD)
    return t

def obb_to_hbb(pts8):
    xs = pts8[0::2]; ys = pts8[1::2]
    x1, y1, x2, y2 = min(xs), min(ys), max(xs), max(ys)
    return [x1, y1, x2, y2]

class DOTAIndex:
    def __init__(self, root):
        self.root = Path(root)
        self.img_dir = self.root / "Images"
        self.lbl_dir = self.root / "labelTxt"
        assert self.img_dir.is_dir() and self.lbl_dir.is_dir(), "DOTA folders not found."
        self.img_paths = sorted([p for p in self.img_dir.iterdir() if p.suffix.lower() in [".jpg",".png",".jpeg"]])
        self.records = []
        self._load()

    def _load(self):
        for img_path in self.img_paths:
            name = img_path.stem
            txt = self.lbl_dir / f"{name}.txt"
            boxes, labels = [], []
            if txt.exists():
                with open(txt, "r") as f:
                    for line in f:
                        parts = line.strip().split()
                        if len(parts) < 10:
                            continue
                        pts = list(map(float, parts[:8]))
                        cls = parts[8]
                        x1, y1, x2, y2 = obb_to_hbb(pts)
                        boxes.append([x1, y1, x2, y2])
                        labels.append(cls)
            if boxes:
                boxes = np.array(boxes, np.float32)
                labels = np.array(labels, dtype=object)
                classes = set(labels.tolist())
            else:
                boxes = np.zeros((0,4), np.float32)
                labels = np.zeros((0,), dtype=object)
                classes = set()
            self.records.append(dict(img_path=img_path, boxes=boxes, labels=labels, classes=classes))

    def class_list(self):
        allc = set()
        for r in self.records:
            allc |= r["classes"]
        return sorted(list(allc))

BASE_CLASSES = ['ship','plane','storage-tank','baseball-diamond','tennis-court',
                'basketball-court','ground-track-field','harbor','bridge','large-vehicle']
NOVEL_CLASSES = ['small-vehicle','helicopter','roundabout','soccer-ball-field','swimming-pool']

dota = DOTAIndex(DOTA_ROOT)
all_classes = dota.class_list()
print(f"Found {len(all_classes)} classes in split:", all_classes)
print("Using base:", BASE_CLASSES)
print("Using novel:", NOVEL_CLASSES)

class EpisodeSampler(Dataset):
    def __init__(self, dota: DOTAIndex, base_classes, n_way=3, k_shot=5, q_query=10, episodes=1000):
        self.dota = dota
        self.n_way, self.k_shot, self.q_query, self.episodes = n_way, k_shot, q_query, episodes
        self.base_classes = base_classes
        self.cls2img = defaultdict(list)
        for i, r in enumerate(dota.records):
            for c in r["classes"]:
                if c in base_classes:
                    self.cls2img[c].append(i)
        available = [c for c in base_classes if len(self.cls2img[c]) >= (k_shot+q_query)]
        if len(available) < n_way:
            print("WARNING: some base classes lack enough images; reduce K/Q or change split.")
        self.base_classes = available if len(available) >= n_way else base_classes

    def __len__(self): return self.episodes

    def _load_img_boxes(self, idx, allowed):
        rec = self.dota.records[idx]
        img = Image.open(rec["img_path"]).convert("RGB")
        img_r, scale, (pad_left, pad_top) = resize_keep_ratio(img)
        img_t = to_tensor_norm(img_r)
        boxes = rec["boxes"] * scale
        boxes[:, [0, 2]] += pad_left
        boxes[:, [1, 3]] += pad_top
        labels = rec["labels"]
        keep = [i for i, c in enumerate(labels) if c in allowed]
        boxes = boxes[keep] if len(keep) else np.zeros((0,4), np.float32)
        labels = labels[keep] if len(keep) else np.array([], dtype=object)
        return img_t, torch.tensor(boxes, dtype=torch.float32), labels

    def __getitem__(self, idx):
        epi_classes = random.sample(self.base_classes, self.n_way)
        allowed = set(epi_classes)
        remap = {c:i for i,c in enumerate(epi_classes)}
        support_imgs, support_boxes, support_labels = [], [], []
        query_imgs, query_boxes, query_labels = [], [], []
        for c in epi_classes:
            ids = random.sample(self.cls2img[c], self.k_shot + self.q_query)
            sup_ids, qry_ids = ids[:self.k_shot], ids[self.k_shot:]
            for sid in sup_ids:
                img_t, boxes, labels = self._load_img_boxes(sid, allowed)
                mask = [i for i, cc in enumerate(labels) if cc == c]
                if len(mask):
                    support_imgs.append(img_t)
                    support_boxes.append(boxes[mask])
                    support_labels.append(torch.full((len(mask),), remap[c], dtype=torch.long))
            for qid in qry_ids:
                img_t, boxes, labels = self._load_img_boxes(qid, allowed)
                if boxes.shape[0] == 0:
                    continue
                lbs = torch.tensor([remap[cc] for cc in labels], dtype=torch.long)
                query_imgs.append(img_t)
                query_boxes.append(boxes)
                query_labels.append(lbs)
        pack = lambda xs: torch.stack(xs) if len(xs) and xs[0].ndim==3 else xs
        return {
            "support_imgs": pack(support_imgs),
            "support_boxes": support_boxes,
            "support_labels": support_labels,
            "query_imgs": pack(query_imgs),
            "query_boxes": query_boxes,
            "query_labels": query_labels,
            "epi_classes": epi_classes
        }

class ProtoFRCNN(nn.Module):
    def __init__(self):
        super().__init__()
        m = fasterrcnn_resnet50_fpn(weights="DEFAULT")
        self.backbone = m.backbone
        self.rpn = m.rpn
        self.roi_pool = m.roi_heads.box_roi_pool
        self.box_head = m.roi_heads.box_head
        self.feat_dim = 1024

    def rpn_proposals(self, imgs, topk=800):
        # Wrap tensor in ImageList for RPN compatibility
        image_sizes = [(imgs.shape[-2], imgs.shape[-1])] * imgs.shape[0]  # [H, W] for each image
        image_list = ImageList(tensors=imgs, image_sizes=image_sizes)
        feats = self.backbone(imgs)
        props, _ = self.rpn(image_list, feats)
        props = [p[:topk] for p in props]
        return props, feats

    def roi_feats(self, imgs, boxes):
        feats = self.backbone(imgs)
        box_indices = []
        for i, b in enumerate(boxes):
            box_indices.append(torch.full((b.shape[0],), i, dtype=torch.long, device=b.device))
        box_indices = torch.cat(box_indices) if box_indices else torch.tensor([], dtype=torch.long, device=imgs.device)
        boxes_flat = torch.cat(boxes, dim=0) if boxes else torch.tensor([], device=imgs.device)
        roi = self.roi_pool(feats, [boxes_flat], [(imgs.shape[-2], imgs.shape[-1])] * len(boxes))
        emb = self.box_head(roi)
        emb = F.normalize(emb, dim=1)
        return emb

# Unchanged functions: build_prototypes, cosine_logits, episode_train_step, infer_on_image, evaluate_ap50, visualize
def build_prototypes(model, imgs, boxes, labels, n_way):
    feats = model.roi_feats(imgs, boxes)
    labs = torch.cat(labels, 0).to(feats.device)
    protos = []
    for c in range(n_way):
        mask = (labs == c)
        if mask.any():
            p = feats[mask].mean(0)
        else:
            p = torch.zeros(model.feat_dim, device=feats.device)
        protos.append(p)
    protos = F.normalize(torch.stack(protos, 0), dim=1)
    return protos

def cosine_logits(q_feats, protos, temp=0.1):
    q_feats = F.normalize(q_feats, dim=1)
    return (q_feats @ protos.t()) / temp

def episode_train_step(model, episode, n_way, temp=0.1):
    s_imgs = episode["support_imgs"].to(DEVICE)
    s_boxes = [b.to(DEVICE) for b in episode["support_boxes"]]
    s_labs = [l.to(DEVICE) for l in episode["support_labels"]]
    q_imgs = episode["query_imgs"].to(DEVICE)
    q_boxes = [b.to(DEVICE) for b in episode["query_boxes"]]
    q_labs = [l.to(DEVICE) for l in episode["query_labels"]]
    
    model_ref = model.module if isinstance(model, nn.DataParallel) else model
    with torch.no_grad():
        protos = build_prototypes(model_ref, s_imgs, s_boxes, s_labs, n_way)
    q_feats = model_ref.roi_feats(q_imgs, q_boxes)
    y = torch.cat(q_labs, 0).to(DEVICE)
    
    logits = cosine_logits(q_feats, protos, temp)
    loss = F.cross_entropy(logits, y)
    acc = (logits.argmax(1) == y).float().mean().item()
    return loss, acc

@torch.no_grad()
def infer_on_image(model, protos, img_t, conf=0.5, nms_iou=0.5):
    model.eval()
    img_t = img_t.unsqueeze(0).to(DEVICE)
    model_ref = model.module if isinstance(model, nn.DataParallel) else model
    proposals, _ = model_ref.rpn_proposals(img_t, topk=800)
    feats = model_ref.roi_feats(img_t, proposals)
    logits = cosine_logits(feats, protos, temp=0.1)
    probs = logits.softmax(-1)
    scores, labels = probs.max(1)
    keep_boxes, keep_scores, keep_labels = [], [], []
    for c in range(protos.size(0)):
        mask = (labels == c) & (scores > conf)
        if mask.sum() == 0:
            continue
        boxes_c = proposals[0][mask]
        scores_c = scores[mask]
        keep = nms(boxes_c, scores_c, nms_iou)
        keep_boxes.append(boxes_c[keep].cpu())
        keep_scores.append(scores_c[keep].cpu())
        keep_labels.append(torch.full((len(keep),), c, dtype=torch.long))
    if len(keep_boxes) == 0:
        return torch.empty((0,4)), torch.empty((0,)), torch.empty((0,), dtype=torch.long)
    return torch.cat(keep_boxes), torch.cat(keep_scores), torch.cat(keep_labels)

@torch.no_grad()
def evaluate_ap50(model, prototypes, dota, novel_classes, n_way, num_eval=50):
    model.eval()
    model_ref = model.module if isinstance(model, nn.DataParallel) else model
    ap_scores = []
    cand = [i for i, r in enumerate(dota.records) if any(c in novel_classes for c in r["classes"])]
    if len(cand) < num_eval:
        print(f"Only {len(cand)} candidate images found; evaluating on those.")
        num_eval = len(cand)
    eval_ids = random.sample(cand, num_eval)
    
    for idx in eval_ids:
        rec = dota.records[idx]
        img = Image.open(rec["img_path"]).convert("RGB")
        img_r, scale, (pad_left, pad_top) = resize_keep_ratio(img)
        img_t = to_tensor_norm(img_r)
        gt_boxes = torch.tensor(rec["boxes"] * scale, dtype=torch.float32)
        gt_boxes[:, [0, 2]] += pad_left
        gt_boxes[:, [1, 3]] += pad_top
        gt_labels = [novel_classes.index(c) for c in rec["labels"] if c in novel_classes]
        if not gt_labels:
            continue
        gt_labels = torch.tensor(gt_labels, dtype=torch.long)
        
        pred_boxes, pred_scores, pred_labels = infer_on_image(model_ref, prototypes, img_t, conf=0.5)
        if pred_boxes.shape[0] == 0:
            ap_scores.append(0.0)
            continue
        
        ious = box_iou(pred_boxes, gt_boxes)
        tp = torch.zeros_like(pred_scores, dtype=torch.bool)
        matched = torch.zeros(gt_boxes.shape[0], dtype=torch.bool)
        for i in range(pred_scores.shape[0]):
            if pred_labels[i] not in gt_labels:
                continue
            valid_ious = ious[i][gt_labels == pred_labels[i]]
            valid_gt_idx = (gt_labels == pred_labels[i]).nonzero(as_tuple=True)[0]
            if valid_ious.numel() == 0:
                continue
            max_iou, max_idx = valid_ious.max(dim=0)
            if max_iou >= 0.5 and not matched[valid_gt_idx[max_idx]]:
                tp[i] = True
                matched[valid_gt_idx[max_idx]] = True
        
        precisions = torch.cumsum(tp, dim=0) / (torch.arange(tp.shape[0], device=tp.device) + 1)
        recalls = torch.cumsum(tp, dim=0) / max(1, gt_labels.shape[0])
        ap = precisions[recalls > 0].mean().item() if (recalls > 0).any() else 0.0
        ap_scores.append(ap)
    
    return np.mean(ap_scores) if ap_scores else 0.0

def visualize(img_t, boxes, scores, labels, class_names, out_path):
    arr = img_t.cpu().permute(1,2,0).numpy()
    arr = (arr * np.array(STD) + np.array(MEAN)).clip(0,1)
    plt.figure(figsize=(10,8)); plt.imshow(arr)
    for b, s, l in zip(boxes, scores, labels):
        x1, y1, x2, y2 = b.tolist()
        plt.gca().add_patch(plt.Rectangle((x1,y1), x2-x1, y2-y1, fill=False, lw=2, ec="lime"))
        plt.text(x1, y1-2, f"{class_names[l]} {s:.2f}", fontsize=9,
                 bbox=dict(fc="yellow", alpha=0.5, ec="none"))
    plt.axis("off"); plt.tight_layout(); plt.savefig(out_path, dpi=150); plt.close()

N_WAY = 3
K_SHOT = 5
Q_QUERY = 5
EPISODES = 600
MAX_ITERS = 1000
LR = 2e-4
TEMP = 0.1
CONF_THRESH = 0.5

ep_ds = EpisodeSampler(dota, BASE_CLASSES, n_way=N_WAY, k_shot=K_SHOT, q_query=Q_QUERY, episodes=EPISODES)
loader = DataLoader(ep_ds, batch_size=2, shuffle=True, num_workers=2, collate_fn=lambda x: x[0])

model = ProtoFRCNN().to(DEVICE)
if torch.cuda.device_count() > 1:
    print(f"Using {torch.cuda.device_count()} GPUs!")
    model = nn.DataParallel(model)
model.to(DEVICE)

opt = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=5e-5)
scheduler = StepLR(opt, step_size=250, gamma=0.5)

model.train()
for it, episode in enumerate(loader, 1):
    loss, acc = episode_train_step(model, episode, N_WAY, temp=TEMP)
    opt.zero_grad()
    loss.backward()
    nn.utils.clip_grad_norm_(model.parameters(), 5.0)
    opt.step()
    scheduler.step()
    if it % 20 == 0:
        print(f"[iter {it:04d}] loss={loss.item():.4f} acc={acc*100:.2f}% lr={scheduler.get_last_lr()[0]:.6f}")
    if it >= MAX_ITERS:
        break

model.eval()
cls2img_novel = defaultdict(list)
for i, r in enumerate(dota.records):
    for c in r["classes"]:
        if c in NOVEL_CLASSES:
            cls2img_novel[c].append(i)

chosen_novel = NOVEL_CLASSES[:N_WAY]
sup_imgs, sup_boxes, sup_labels = [], [], []
for cid, c in enumerate(chosen_novel):
    if len(cls2img_novel[c]) < K_SHOT:
        print(f"Novel class '{c}' has < {K_SHOT} images. Pick a different split or lower K_SHOT.")
        continue
    ids = random.sample(cls2img_novel[c], K_SHOT)
    for idx in ids:
        rec = dota.records[idx]
        img = Image.open(rec["img_path"]).convert("RGB")
        img_r, scale, (pad_left, pad_top) = resize_keep_ratio(img)
        img_t = to_tensor_norm(img_r).to(DEVICE)
        mask = [i for i, cc in enumerate(rec["labels"]) if cc == c]
        if len(mask) == 0:
            continue
        boxes = rec["boxes"][mask] * scale
        boxes[:, [0, 2]] += pad_left
        boxes[:, [1, 3]] += pad_top
        boxes = torch.tensor(boxes, dtype=torch.float32, device=DEVICE)
        sup_imgs.append(img_t)
        sup_boxes.append(boxes)
        sup_labels.append(torch.full((len(mask),), cid, dtype=torch.long, device=DEVICE))

if len(sup_imgs) == 0:
    raise RuntimeError("No novel support found. Adjust NOVEL_CLASSES or check dataset.")

sup_imgs = torch.stack(sup_imgs, 0)
with torch.no_grad():
    model_ref = model.module if isinstance(model, nn.DataParallel) else model
    prototypes = build_prototypes(model_ref, sup_imgs, sup_boxes, sup_labels, N_WAY)

ap50 = evaluate_ap50(model, prototypes, dota, chosen_novel, N_WAY)
print(f"AP50 on novel classes {chosen_novel}: {ap50*100:.2f}%")

cand = [i for i, r in enumerate(dota.records) if any(c in chosen_novel for c in r["classes"])]
if len(cand):
    idx = random.choice(cand)
    rec = dota.records[idx]
    img = Image.open(rec["img_path"]).convert("RGB")
    img_r, scale, (pad_left, pad_top) = resize_keep_ratio(img)
    img_t = to_tensor_norm(img_r)
    boxes = rec["boxes"] * scale
    boxes[:, [0, 2]] += pad_left
    boxes[:, [1, 3]] += pad_top
    model_ref = model.module if isinstance(model, nn.DataParallel) else model
    boxes, scores, labels = infer_on_image(model_ref, prototypes, img_t, conf=CONF_THRESH)
    out_dir = Path("./outputs_dota"); out_dir.mkdir(parents=True, exist_ok=True)
    out_path = out_dir / f"viz_{Path(rec['img_path']).stem}.png"
    visualize(img_t, boxes, scores, labels, chosen_novel, str(out_path))
    print("Saved visualization:", out_path)
else:
    print("No candidate novel image found for viz; adjust N_WAY or NOVEL_CLASSES.")
# Out:
# Torch: 2.6.0+cu124 TorchVision: 0.21.0+cu124 Device: cuda
# Number of GPUs: 1
# Found 15 classes in split: ['baseball-diamond', 'basketball-court', 'bridge', 'ground-track-field', 'harbor', 'helicopter', 'large-vehicle', 'plane', 'roundabout', 'ship', 'small-vehicle', 'soccer-ball-field', 'storage-tank', 'swimming-pool', 'tennis-court']
# Using base: ['ship', 'plane', 'storage-tank', 'baseball-diamond', 'tennis-court', 'basketball-court', 'ground-track-field', 'harbor', 'bridge', 'large-vehicle']
# Using novel: ['small-vehicle', 'helicopter', 'roundabout', 'soccer-ball-field', 'swimming-pool']
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:00<00:00, 215MB/s]
# [iter 0020] loss=0.8915 acc=52.71% lr=0.000200
# [iter 0040] loss=1.0901 acc=87.27% lr=0.000200
# [iter 0060] loss=1.0217 acc=61.29% lr=0.000200
# [iter 0080] loss=1.0988 acc=52.28% lr=0.000200
# [iter 0100] loss=1.0944 acc=16.84% lr=0.000200
# [iter 0120] loss=1.0916 acc=7.23% lr=0.000200
# [iter 0140] loss=1.0986 acc=45.58% lr=0.000200
# [iter 0160] loss=1.1366 acc=71.04% lr=0.000200
# [iter 0180] loss=0.7864 acc=80.04% lr=0.000200
# [iter 0200] loss=1.0115 acc=67.07% lr=0.000100
# [iter 0220] loss=1.0832 acc=23.23% lr=0.000100
# [iter 0240] loss=1.2436 acc=31.99% lr=0.000100
# [iter 0260] loss=1.1497 acc=44.40% lr=0.000100
# [iter 0280] loss=1.0724 acc=53.85% lr=0.000100
# [iter 0300] loss=1.1104 acc=23.33% lr=0.000100
# AP50 on novel classes ['small-vehicle', 'helicopter', 'roundabout']: 0.00%
# Saved visualization: outputs_dota/viz_P1649.png

# %%
# Out:
# Images.zip  input  labelTxt.zip  lib  outputs_dota  working
